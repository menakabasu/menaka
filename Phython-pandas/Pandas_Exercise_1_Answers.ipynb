# %% [markdown]
# ## Exercise 1: Sales Data

# %%
# All imports
import pandas as pd

# %% [markdown]
# Q1. Import the Sales data

# %%
# Read file

sales = pd.read_csv('sales.csv')
sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-84f8321e4d87> in <cell line: 3>()
#       1 # Read file
#       2
# ----> 3 sales = pd.read_csv('sales.csv')
#       4 sales
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Q2. Read file and set 1st two columns as index

# %%
# Read file and set 1st two columns as index
sales = pd.read_csv('sales.csv', index_col = [0,1])

sales
# Out:
#                                 No_of_Orders      Profit       Sales
# Market       Region
# Africa       Western Africa              251  -12,901.51   78,476.06
#              Southern Africa              85   11,768.58   51,319.50
#              North Africa                182   21,643.08   86,698.89
#              Eastern Africa              110    8,013.04   44,182.60
#              Central Africa              103   15,606.30   61,689.99
# Asia Pacific Western Asia                382  -16,766.90  124,312.24
#              Southern Asia               469   67,998.76  351,806.60
#              Southeastern Asia           533   20,948.84  329,751.38
#              Oceania                     646   54,734.02  408,002.98
#              Eastern Asia                414   72,805.10  315,390.77
#              Central Asia                 37   -2,649.76    8,190.74
# Europe       Western Europe              964   82,091.27  656,637.14
# ...

# %% [markdown]
# Q3. Display first 3 land last 3 rows of the sales dataframe

# %%
sales.head(3)
# Out:
#                         No_of_Orders    Profit     Sales
# Market Region
# Africa Western Africa            251 -12901.51  78476.06
#        Southern Africa            85  11768.58  51319.50
#        North Africa              182  21643.08  86698.89

# %%
sales.tail(3)
# Out:
#                    No_of_Orders    Profit      Sales
# Market Region
# USCA   Eastern US           443  47462.04  264973.98
#        Central US           356  33697.43  170416.31
#        Canada                49   7246.62   26298.81

# %% [markdown]
# Q4. Display the information about the data stored in data frame

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23 entries, ('Africa', 'Western Africa') to ('USCA', 'Canada')
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_Orders  23 non-null     int64
#  1   Profit        23 non-null     float64
#  2   Sales         23 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 932.0+ bytes

# %% [markdown]
# Q5. Display the statistical information about the data in dataframe

# %%
sales.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %% [markdown]
# Q6. Display the sales column as a series.

# %%
sales["Sales"]

# %% [markdown]
# Q7. Display sales and profit column as a dataframe

# %%
sales[["Sales", "Profit"]]

# %% [markdown]
# Q8. Display the data for Southern Asia

# %%
sales.loc["Southern Asia"]

# %% [markdown]
# Q9. Display Sales and Profit data for Western Africa Southern Africa and North Africa

# %%
sales.loc[["Western Africa", "Southern Africa", "North Africa"] , ["Sales", "Profit"]]
sales.iloc[0:3, 2:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3249d73bfa88> in <cell line: 1>()
# ----> 1 sales.loc[["Western Africa", "Southern Africa", "North Africa"] , ["Sales", "Profit"]]
#       2 sales.iloc[0:3, 2:4]
#
# NameError: name 'sales' is not defined

# %% [markdown]
# Q10. Display Markets with Sales >300000

# %%
sales["Sales"] > 300000
